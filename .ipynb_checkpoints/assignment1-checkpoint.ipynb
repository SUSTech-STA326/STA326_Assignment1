# %% [markdown]
# # STA326 Assignment 1: Data Collection
# This is an assignment that is openly available for the Data Science Practice (STA326).
#
# The assignment encapsulates a holistic approach towards data collection and analysis, covering a spectrum of data formats and sources. Our objective is to amass, process, and scrutinize data to unearth significant insights. The methodology is sectioned into four pivotal tasks:
# - Web scraping
# - JSON file analysis
# - Working with CSV files
# - Data Cleaning

# %%
# Imports
import requests  # send request
from bs4 import BeautifulSoup  # parse web pages
import pandas as pd  # csv
from time import sleep  # wait
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %% [markdown]
# ## Part 1: Web Scraping
#
# In this assignment, we will explore web scraping, which can often include diverse information from website, and also use the data for simple analysis. We take [douban](https://movie.douban.com/top250) as the target website in this assignment.
#
# ### Scraping Rules
#
# 1) If you are using another organization's website for scraping, make sure to check the website's terms & conditions.
#
# 2) Do not request data from the website too aggressively (quickly) with your program (also known as spamming), as this may break the website. Make sure your program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
#
# 3) The layout of a website may change from time to time. Because of this, if you're scraping a website, make sure to revisit the site and rewrite your code as needed.

# %% [markdown]
# ### 1a) Web Scrape
#
# In order to extract the data we want, we’ll start with extracting the whole web.

# %%
# Define a request header (to prevent anti-scraping)
headers = {
    'authority': 'curlconverter.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cache-control': 'max-age=0',
    'if-modified-since': 'Fri, 15 Jul 2022 21:44:42 GMT',
    'if-none-match': 'W/"62d1dfca-3a58"',
    'referer': 'https://curlconverter.com/',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Microsoft Edge";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36 Edg/102.0.1245.30',
}

# %% [markdown]
# This process can be split into three steps:
#
# 1. Make a variable called `url`, that stores the following URL (as a string):
# https://movie.douban.com/top250?start=0
#
# 2. Now, to open the URL, use `requests.get()` and provide `url` and `headers` as its input. Store this in a variable called `page`.
#
# 3. After that, make a variable called `soup` to parse the HTML using `BeautifulSoup`. Consider that there will be a method from `BeautifulSoup` that you'll need to call on to get the content from the page.

# %%
# YOUR CODE HERE
# raise NotImplementedError()
url = "https://movie.douban.com/top250?start=0"
page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
assert url
assert page
assert soup

# %% [markdown]
# ### 1b) Data Extraction
#
# Extract the data (`name` and `star`) from the page and save it in the corresponding list like `movie_name` and `movie_star`.
#
# Make sure you extract it as a string.
#
# To do so, you have to use the soup object created in the above cell.
#
# **Hint**: from your soup variable, you can access this with `soup.select()`

# %%
movie_name = []  # movie name
movie_star = []  # movie star

# YOUR CODE HERE
# raise NotImplementedError()

for movie in soup.select('.hd'):
    name = movie.a.text.strip()
    movie_name.append(name)

for star in soup.select('.rating_num'):
    rating = star.text.strip()
    movie_star.append(rating)

for i in range(len(movie_name)):
    print(f"电影名称: {movie_name[i]}, 评分: {movie_star[i]}")

##### 如果要全部的数据可以使用以下代码，完整数据也已存入output
# for page in range(0, 250, 25): 
#     url = f'https://movie.douban.com/top250?start={page}'
#     page = requests.get(url, headers=headers)
#     soup = BeautifulSoup(page.content, 'html.parser')
    
#     for movie in soup.select('.hd'):
#         name = movie.a.text.strip()
#         movie_name.append(name)
        
#     for star in soup.select('.rating_num'):
#         rating = star.text.strip()
#         movie_star.append(rating)

#     for i in range(len(movie_name)):
#         print(f"电影名称: {movie_name[i]}, 评分: {movie_star[i]}")
# Out:
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 小鞋子
#  / بچه های آسمان
#  / 天堂的孩子  /  小童鞋, 评分: 9.2
# 电影名称: 沉默的羔羊
#  / The Silence of the Lambs
#  / 沉默的羔羊, 评分: 8.9
# 电影名称: 功夫
#  / 功夫3D  /  Kung Fu Hustle, 评分: 8.8
# 电影名称: 布达佩斯大饭店
#  / The Grand Budapest Hotel
#  / 布达佩斯大酒店(港)  /  欢迎来到布达佩斯大饭店(台), 评分: 8.9
# 电影名称: 禁闭岛
#  / Shutter Island
#  / 不赦岛(港)  /  隔离岛(台), 评分: 8.9
# 电影名称: 蝴蝶效应
#  / The Butterfly Effect
#  / 蝴蝶效应, 评分: 8.9
# 电影名称: 哈利·波特与阿兹卡班的囚徒
#  / Harry Potter and the Prisoner of Azkaban
#  / 哈利波特3：阿兹卡班的逃犯(港 / 台), 评分: 9.0
# 电影名称: 致命魔术
#  / The Prestige
#  / 死亡魔法(港)  /  顶尖对决(台), 评分: 8.9
# 电影名称: 心灵捕手
#  / Good Will Hunting
#  / 骄阳似我(港)  /  心灵捕手, 评分: 8.9
# 电影名称: 超脱
#  / Detachment
#  / 人间师格(台), 评分: 9.0
# 电影名称: 低俗小说
#  / Pulp Fiction
#  / 危险人物(港)  /  黑色追缉令(台), 评分: 8.9
# 电影名称: 摩登时代
#  / Modern Times
#  / The Masses  /  Les Temps modernes, 评分: 9.3
# 电影名称: 海豚湾
#  / The Cove
#  / 血色海湾(台)  /  海湾, 评分: 9.3
# 电影名称: 春光乍泄
#  / 春光乍洩
#  / 一起快乐  /  Happy Together, 评分: 9.0
# 电影名称: 喜剧之王
#  / 喜劇之王
#  / King of Comedy, 评分: 8.8
# 电影名称: 美国往事
#  / Once Upon a Time in America
#  / 四海兄弟(台)  /  义薄云天(港), 评分: 9.2
# 电影名称: 致命ID
#  / Identity
#  / 杀人游戏  /  致命身份, 评分: 8.9
# 电影名称: 杀人回忆
#  / 살인의 추억
#  / 谋杀回忆  /  杀手回忆录, 评分: 8.9
# 电影名称: 哈利·波特与密室
#  / Harry Potter and the Chamber of Secrets
#  / 哈利波特2：消失的密室(港 / 台), 评分: 8.9
# 电影名称: 红辣椒
#  / パプリカ
#  / 盗梦侦探(港 / 台), 评分: 9.1
# 电影名称: 七宗罪
#  / Se7en
#  / 火线追缉令(台)  /  7宗罪, 评分: 8.8
# 电影名称: 加勒比海盗
#  / Pirates of the Caribbean: The Curse of the Black Pearl
#  / 加勒比海盗1：黑珍珠号的诅咒  /  神鬼奇航：鬼盗船魔咒(台), 评分: 8.8
# 电影名称: 一一
#  / Yi yi  /  Yi yi: A One and a Two, 评分: 9.1
# 电影名称: 狩猎
#  / Jagten
#  / 诬网(港)  /  谎言的烙印(台), 评分: 9.1
# 电影名称: 唐伯虎点秋香
#  / 唐伯虎點秋香
#  / Flirting Scholar, 评分: 8.7
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 小鞋子
#  / بچه های آسمان
#  / 天堂的孩子  /  小童鞋, 评分: 9.2
# 电影名称: 沉默的羔羊
#  / The Silence of the Lambs
#  / 沉默的羔羊, 评分: 8.9
# 电影名称: 功夫
#  / 功夫3D  /  Kung Fu Hustle, 评分: 8.8
# 电影名称: 布达佩斯大饭店
#  / The Grand Budapest Hotel
#  / 布达佩斯大酒店(港)  /  欢迎来到布达佩斯大饭店(台), 评分: 8.9
# 电影名称: 禁闭岛
#  / Shutter Island
#  / 不赦岛(港)  /  隔离岛(台), 评分: 8.9
# 电影名称: 蝴蝶效应
#  / The Butterfly Effect
#  / 蝴蝶效应, 评分: 8.9
# 电影名称: 哈利·波特与阿兹卡班的囚徒
#  / Harry Potter and the Prisoner of Azkaban
#  / 哈利波特3：阿兹卡班的逃犯(港 / 台), 评分: 9.0
# 电影名称: 致命魔术
#  / The Prestige
#  / 死亡魔法(港)  /  顶尖对决(台), 评分: 8.9
# 电影名称: 心灵捕手
#  / Good Will Hunting
#  / 骄阳似我(港)  /  心灵捕手, 评分: 8.9
# 电影名称: 超脱
#  / Detachment
#  / 人间师格(台), 评分: 9.0
# 电影名称: 低俗小说
#  / Pulp Fiction
#  / 危险人物(港)  /  黑色追缉令(台), 评分: 8.9
# 电影名称: 摩登时代
#  / Modern Times
#  / The Masses  /  Les Temps modernes, 评分: 9.3
# 电影名称: 海豚湾
#  / The Cove
#  / 血色海湾(台)  /  海湾, 评分: 9.3
# 电影名称: 春光乍泄
#  / 春光乍洩
#  / 一起快乐  /  Happy Together, 评分: 9.0
# 电影名称: 喜剧之王
#  / 喜劇之王
#  / King of Comedy, 评分: 8.8
# 电影名称: 美国往事
#  / Once Upon a Time in America
#  / 四海兄弟(台)  /  义薄云天(港), 评分: 9.2
# 电影名称: 致命ID
#  / Identity
#  / 杀人游戏  /  致命身份, 评分: 8.9
# 电影名称: 杀人回忆
#  / 살인의 추억
#  / 谋杀回忆  /  杀手回忆录, 评分: 8.9
# 电影名称: 哈利·波特与密室
#  / Harry Potter and the Chamber of Secrets
#  / 哈利波特2：消失的密室(港 / 台), 评分: 8.9
# 电影名称: 红辣椒
#  / パプリカ
#  / 盗梦侦探(港 / 台), 评分: 9.1
# 电影名称: 七宗罪
#  / Se7en
#  / 火线追缉令(台)  /  7宗罪, 评分: 8.8
# 电影名称: 加勒比海盗
#  / Pirates of the Caribbean: The Curse of the Black Pearl
#  / 加勒比海盗1：黑珍珠号的诅咒  /  神鬼奇航：鬼盗船魔咒(台), 评分: 8.8
# 电影名称: 一一
#  / Yi yi  /  Yi yi: A One and a Two, 评分: 9.1
# 电影名称: 狩猎
#  / Jagten
#  / 诬网(港)  /  谎言的烙印(台), 评分: 9.1
# 电影名称: 唐伯虎点秋香
#  / 唐伯虎點秋香
#  / Flirting Scholar, 评分: 8.7
# 电影名称: 7号房的礼物
#  / 7번방의 선물
#  / 戆爸的礼物(港)  /  7号囚房的礼物, 评分: 8.9
# 电影名称: 被嫌弃的松子的一生
#  / 嫌われ松子の一生
#  / 花样奇缘(港)  /  令人讨厌的松子的一生(台), 评分: 8.9
# 电影名称: 蝙蝠侠：黑暗骑士崛起
#  / The Dark Knight Rises
#  / 蝙蝠侠前传3：黑暗骑士崛起  /  黑暗骑士：黎明升起(台), 评分: 8.9
# 电影名称: 爱在黎明破晓前
#  / Before Sunrise
#  / 情留半天(港)  /  爱在黎明破晓时(台), 评分: 8.8
# 电影名称: 请以你的名字呼唤我
#  / Call Me by Your Name
#  / 以你的名字呼唤我(港 / 台), 评分: 8.8
# 电影名称: 甜蜜蜜
#  / Comrades: Almost a Love Story, 评分: 8.9
# 电影名称: 断背山
#  / Brokeback Mountain
#  / 断臂山  /  BBM, 评分: 8.8
# 电影名称: 剪刀手爱德华
#  / Edward Scissorhands
#  / 幻海奇缘(港)  /  剪刀手爱德华, 评分: 8.7
# 电影名称: 入殓师
#  / おくりびと
#  / 礼仪师之奏鸣曲(港)  /  礼仪师(台), 评分: 8.9
# 电影名称: 第六感
#  / The Sixth Sense
#  / 鬼眼(港)  /  灵异第六感(台), 评分: 8.9
# 电影名称: 重庆森林
#  / 重慶森林
#  / Chungking Express, 评分: 8.8
# 电影名称: 超能陆战队
#  / Big Hero 6
#  / 大英雄联盟(港)  /  大英雄天团(台), 评分: 8.7
# 电影名称: 勇敢的心
#  / Braveheart
#  / 惊世未了缘(港)  /  梅尔吉勃逊之英雄本色(台), 评分: 8.9
# 电影名称: 爱在日落黄昏时
#  / Before Sunset
#  / 日落巴黎(港)  /  爱在日落巴黎时(台), 评分: 8.9
# 电影名称: 幽灵公主
#  / もののけ姫
#  / 魔法公主(港)  /  魔法公主(台), 评分: 8.9
# 电影名称: 菊次郎的夏天
#  / 菊次郎の夏
#  / 菊次郎之夏  /  Kikujirô no natsu, 评分: 8.9
# 电影名称: 寄生虫
#  / 기생충
#  / 寄生上流(台)  /  上流寄生族(港), 评分: 8.8
# 电影名称: 借东西的小人阿莉埃蒂
#  / 借りぐらしのアリエッティ
#  / 借物少女艾莉缇(台)  /  借东西的小矮人亚莉亚蒂(港), 评分: 8.9
# 电影名称: 消失的爱人
#  / Gone Girl
#  / 失踪的女孩  /  失踪女孩, 评分: 8.7
# 电影名称: 无人知晓
#  / 誰も知らない
#  / 谁知赤子心(港)  /  无人知晓的夏日清晨(台), 评分: 9.1
# 电影名称: 阳光灿烂的日子
#  / In the Heat of the Sun, 评分: 8.8
# 电影名称: 完美的世界
#  / A Perfect World
#  / 强盗保镳, 评分: 9.1
# 电影名称: 天使爱美丽
#  / Le fabuleux destin d'Amélie Poulain
#  / 艾蜜莉的异想世界(台)  /  天使艾米莉, 评分: 8.7
# 电影名称: 倩女幽魂
#  / 倩女幽魂(87版)  /  倩女幽魂：妖魔道, 评分: 8.8
# 电影名称: 时空恋旅人
#  / About Time
#  / 回到最爱的一天(港)  /  真爱每一天(台), 评分: 8.8
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 小鞋子
#  / بچه های آسمان
#  / 天堂的孩子  /  小童鞋, 评分: 9.2
# 电影名称: 沉默的羔羊
#  / The Silence of the Lambs
#  / 沉默的羔羊, 评分: 8.9
# 电影名称: 功夫
#  / 功夫3D  /  Kung Fu Hustle, 评分: 8.8
# 电影名称: 布达佩斯大饭店
#  / The Grand Budapest Hotel
#  / 布达佩斯大酒店(港)  /  欢迎来到布达佩斯大饭店(台), 评分: 8.9
# 电影名称: 禁闭岛
#  / Shutter Island
#  / 不赦岛(港)  /  隔离岛(台), 评分: 8.9
# 电影名称: 蝴蝶效应
#  / The Butterfly Effect
#  / 蝴蝶效应, 评分: 8.9
# 电影名称: 哈利·波特与阿兹卡班的囚徒
#  / Harry Potter and the Prisoner of Azkaban
#  / 哈利波特3：阿兹卡班的逃犯(港 / 台), 评分: 9.0
# 电影名称: 致命魔术
#  / The Prestige
#  / 死亡魔法(港)  /  顶尖对决(台), 评分: 8.9
# 电影名称: 心灵捕手
#  / Good Will Hunting
#  / 骄阳似我(港)  /  心灵捕手, 评分: 8.9
# 电影名称: 超脱
#  / Detachment
#  / 人间师格(台), 评分: 9.0
# 电影名称: 低俗小说
#  / Pulp Fiction
#  / 危险人物(港)  /  黑色追缉令(台), 评分: 8.9
# 电影名称: 摩登时代
#  / Modern Times
#  / The Masses  /  Les Temps modernes, 评分: 9.3
# 电影名称: 海豚湾
#  / The Cove
#  / 血色海湾(台)  /  海湾, 评分: 9.3
# 电影名称: 春光乍泄
#  / 春光乍洩
#  / 一起快乐  /  Happy Together, 评分: 9.0
# 电影名称: 喜剧之王
#  / 喜劇之王
#  / King of Comedy, 评分: 8.8
# 电影名称: 美国往事
#  / Once Upon a Time in America
#  / 四海兄弟(台)  /  义薄云天(港), 评分: 9.2
# 电影名称: 致命ID
#  / Identity
#  / 杀人游戏  /  致命身份, 评分: 8.9
# 电影名称: 杀人回忆
#  / 살인의 추억
#  / 谋杀回忆  /  杀手回忆录, 评分: 8.9
# 电影名称: 哈利·波特与密室
#  / Harry Potter and the Chamber of Secrets
#  / 哈利波特2：消失的密室(港 / 台), 评分: 8.9
# 电影名称: 红辣椒
#  / パプリカ
#  / 盗梦侦探(港 / 台), 评分: 9.1
# 电影名称: 七宗罪
#  / Se7en
#  / 火线追缉令(台)  /  7宗罪, 评分: 8.8
# 电影名称: 加勒比海盗
#  / Pirates of the Caribbean: The Curse of the Black Pearl
#  / 加勒比海盗1：黑珍珠号的诅咒  /  神鬼奇航：鬼盗船魔咒(台), 评分: 8.8
# 电影名称: 一一
#  / Yi yi  /  Yi yi: A One and a Two, 评分: 9.1
# 电影名称: 狩猎
#  / Jagten
#  / 诬网(港)  /  谎言的烙印(台), 评分: 9.1
# 电影名称: 唐伯虎点秋香
#  / 唐伯虎點秋香
#  / Flirting Scholar, 评分: 8.7
# 电影名称: 7号房的礼物
#  / 7번방의 선물
#  / 戆爸的礼物(港)  /  7号囚房的礼物, 评分: 8.9
# 电影名称: 被嫌弃的松子的一生
#  / 嫌われ松子の一生
#  / 花样奇缘(港)  /  令人讨厌的松子的一生(台), 评分: 8.9
# 电影名称: 蝙蝠侠：黑暗骑士崛起
#  / The Dark Knight Rises
#  / 蝙蝠侠前传3：黑暗骑士崛起  /  黑暗骑士：黎明升起(台), 评分: 8.9
# 电影名称: 爱在黎明破晓前
#  / Before Sunrise
#  / 情留半天(港)  /  爱在黎明破晓时(台), 评分: 8.8
# 电影名称: 请以你的名字呼唤我
#  / Call Me by Your Name
#  / 以你的名字呼唤我(港 / 台), 评分: 8.8
# 电影名称: 甜蜜蜜
#  / Comrades: Almost a Love Story, 评分: 8.9
# 电影名称: 断背山
#  / Brokeback Mountain
#  / 断臂山  /  BBM, 评分: 8.8
# 电影名称: 剪刀手爱德华
#  / Edward Scissorhands
#  / 幻海奇缘(港)  /  剪刀手爱德华, 评分: 8.7
# 电影名称: 入殓师
#  / おくりびと
#  / 礼仪师之奏鸣曲(港)  /  礼仪师(台), 评分: 8.9
# 电影名称: 第六感
#  / The Sixth Sense
#  / 鬼眼(港)  /  灵异第六感(台), 评分: 8.9
# 电影名称: 重庆森林
#  / 重慶森林
#  / Chungking Express, 评分: 8.8
# 电影名称: 超能陆战队
#  / Big Hero 6
#  / 大英雄联盟(港)  /  大英雄天团(台), 评分: 8.7
# 电影名称: 勇敢的心
#  / Braveheart
#  / 惊世未了缘(港)  /  梅尔吉勃逊之英雄本色(台), 评分: 8.9
# 电影名称: 爱在日落黄昏时
#  / Before Sunset
#  / 日落巴黎(港)  /  爱在日落巴黎时(台), 评分: 8.9
# 电影名称: 幽灵公主
#  / もののけ姫
#  / 魔法公主(港)  /  魔法公主(台), 评分: 8.9
# 电影名称: 菊次郎的夏天
#  / 菊次郎の夏
#  / 菊次郎之夏  /  Kikujirô no natsu, 评分: 8.9
# 电影名称: 寄生虫
#  / 기생충
#  / 寄生上流(台)  /  上流寄生族(港), 评分: 8.8
# 电影名称: 借东西的小人阿莉埃蒂
#  / 借りぐらしのアリエッティ
#  / 借物少女艾莉缇(台)  /  借东西的小矮人亚莉亚蒂(港), 评分: 8.9
# 电影名称: 消失的爱人
#  / Gone Girl
#  / 失踪的女孩  /  失踪女孩, 评分: 8.7
# 电影名称: 无人知晓
#  / 誰も知らない
#  / 谁知赤子心(港)  /  无人知晓的夏日清晨(台), 评分: 9.1
# 电影名称: 阳光灿烂的日子
#  / In the Heat of the Sun, 评分: 8.8
# 电影名称: 完美的世界
#  / A Perfect World
#  / 强盗保镳, 评分: 9.1
# 电影名称: 天使爱美丽
#  / Le fabuleux destin d'Amélie Poulain
#  / 艾蜜莉的异想世界(台)  /  天使艾米莉, 评分: 8.7
# 电影名称: 倩女幽魂
#  / 倩女幽魂(87版)  /  倩女幽魂：妖魔道, 评分: 8.8
# 电影名称: 时空恋旅人
#  / About Time
#  / 回到最爱的一天(港)  /  真爱每一天(台), 评分: 8.8
# 电影名称: 小森林 夏秋篇
#  / リトル・フォレスト 夏・秋
#  / 小森食光 / 夏秋篇(台), 评分: 9.0
# 电影名称: 未麻的部屋
#  / Perfect Blue
#  / 蓝色恐惧(港 / 台), 评分: 9.1
# 电影名称: 哈利·波特与火焰杯
#  / Harry Potter and the Goblet of Fire
#  / 哈利波特4：火杯的考验(港 / 台), 评分: 8.8
# 电影名称: 侧耳倾听
#  / 耳をすませば
#  / 心之谷(台)  /  梦幻街少女(港), 评分: 8.9
# 电影名称: 驯龙高手
#  / How to Train Your Dragon
#  / 驯龙记(港), 评分: 8.8
# 电影名称: 幸福终点站
#  / The Terminal
#  / 机场客运站(港)  /  航站情缘(台), 评分: 8.8
# 电影名称: 一个叫欧维的男人决定去死
#  / En man som heter Ove
#  / 明天别再来敲门(台)  /  想死冇咁易(港), 评分: 8.9
# 电影名称: 怪兽电力公司
#  / Monsters, Inc.
#  / 怪兽公司(港)  /  怪物公司, 评分: 8.8
# 电影名称: 教父3
#  / The Godfather: Part III
#  / 教父第三集  /  教父 III, 评分: 9.0
# 电影名称: 小森林 冬春篇
#  / リトル・フォレスト 冬・春
#  / 小森食光 / 冬春篇(台), 评分: 9.0
# 电影名称: 玩具总动员3
#  / Toy Story 3
#  / 反斗奇兵3(港)  /  玩具的故事3, 评分: 8.9
# 电影名称: 傲慢与偏见
#  / Pride & Prejudice
#  / 傲慢与偏见2005  /  Pride And Prejudice, 评分: 8.7
# 电影名称: 新世界
#  / 신세계
#  / 暗黑新世界(台)  /  New World, 评分: 8.9
# 电影名称: 茶馆
#  / The Teahouse, 评分: 9.6
# 电影名称: 萤火之森
#  / 蛍火の杜へ
#  / 萤火之社  /  Hotarubi no mori e, 评分: 8.9
# 电影名称: 釜山行
#  / 부산행
#  / 尸杀列车(港)  /  尸速列车(台), 评分: 8.6
# 电影名称: 被解救的姜戈
#  / Django Unchained
#  / 被解放的姜戈  /  决杀令(台), 评分: 8.8
# 电影名称: 神偷奶爸
#  / Despicable Me
#  / 卑鄙的我  /  坏蛋奖门人(港), 评分: 8.7
# 电影名称: 色，戒
#  / 色|戒  /  色·戒, 评分: 8.7
# 电影名称: 告白
#  / 自白  /  母亲, 评分: 8.8
# 电影名称: 哪吒闹海
#  / Prince Nezha's Triumph Against Dragon King  /  Nezha Conquers the Dragon King, 评分: 9.2
# 电影名称: 玛丽和马克思
#  / Mary and Max
#  / 巧克力情缘(台)  /  同是天涯寂寞客, 评分: 9.0
# 电影名称: 九品芝麻官
#  / 九品芝麻官之白面包青天  /  Hail the Judge, 评分: 8.7
# 电影名称: 大鱼
#  / Big Fish
#  / 大鱼奇缘(港)  /  大智若鱼(台), 评分: 8.8
# 电影名称: 喜宴
#  / 囍宴
#  / The Wedding Banquet, 评分: 9.0
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 小鞋子
#  / بچه های آسمان
#  / 天堂的孩子  /  小童鞋, 评分: 9.2
# 电影名称: 沉默的羔羊
#  / The Silence of the Lambs
#  / 沉默的羔羊, 评分: 8.9
# 电影名称: 功夫
#  / 功夫3D  /  Kung Fu Hustle, 评分: 8.8
# 电影名称: 布达佩斯大饭店
#  / The Grand Budapest Hotel
#  / 布达佩斯大酒店(港)  /  欢迎来到布达佩斯大饭店(台), 评分: 8.9
# 电影名称: 禁闭岛
#  / Shutter Island
#  / 不赦岛(港)  /  隔离岛(台), 评分: 8.9
# 电影名称: 蝴蝶效应
#  / The Butterfly Effect
#  / 蝴蝶效应, 评分: 8.9
# 电影名称: 哈利·波特与阿兹卡班的囚徒
#  / Harry Potter and the Prisoner of Azkaban
#  / 哈利波特3：阿兹卡班的逃犯(港 / 台), 评分: 9.0
# 电影名称: 致命魔术
#  / The Prestige
#  / 死亡魔法(港)  /  顶尖对决(台), 评分: 8.9
# 电影名称: 心灵捕手
#  / Good Will Hunting
#  / 骄阳似我(港)  /  心灵捕手, 评分: 8.9
# 电影名称: 超脱
#  / Detachment
#  / 人间师格(台), 评分: 9.0
# 电影名称: 低俗小说
#  / Pulp Fiction
#  / 危险人物(港)  /  黑色追缉令(台), 评分: 8.9
# 电影名称: 摩登时代
#  / Modern Times
#  / The Masses  /  Les Temps modernes, 评分: 9.3
# 电影名称: 海豚湾
#  / The Cove
#  / 血色海湾(台)  /  海湾, 评分: 9.3
# 电影名称: 春光乍泄
#  / 春光乍洩
#  / 一起快乐  /  Happy Together, 评分: 9.0
# 电影名称: 喜剧之王
#  / 喜劇之王
#  / King of Comedy, 评分: 8.8
# 电影名称: 美国往事
#  / Once Upon a Time in America
#  / 四海兄弟(台)  /  义薄云天(港), 评分: 9.2
# 电影名称: 致命ID
#  / Identity
#  / 杀人游戏  /  致命身份, 评分: 8.9
# 电影名称: 杀人回忆
#  / 살인의 추억
#  / 谋杀回忆  /  杀手回忆录, 评分: 8.9
# 电影名称: 哈利·波特与密室
#  / Harry Potter and the Chamber of Secrets
#  / 哈利波特2：消失的密室(港 / 台), 评分: 8.9
# 电影名称: 红辣椒
#  / パプリカ
#  / 盗梦侦探(港 / 台), 评分: 9.1
# 电影名称: 七宗罪
#  / Se7en
#  / 火线追缉令(台)  /  7宗罪, 评分: 8.8
# 电影名称: 加勒比海盗
#  / Pirates of the Caribbean: The Curse of the Black Pearl
#  / 加勒比海盗1：黑珍珠号的诅咒  /  神鬼奇航：鬼盗船魔咒(台), 评分: 8.8
# 电影名称: 一一
#  / Yi yi  /  Yi yi: A One and a Two, 评分: 9.1
# 电影名称: 狩猎
#  / Jagten
#  / 诬网(港)  /  谎言的烙印(台), 评分: 9.1
# 电影名称: 唐伯虎点秋香
#  / 唐伯虎點秋香
#  / Flirting Scholar, 评分: 8.7
# 电影名称: 7号房的礼物
#  / 7번방의 선물
#  / 戆爸的礼物(港)  /  7号囚房的礼物, 评分: 8.9
# 电影名称: 被嫌弃的松子的一生
#  / 嫌われ松子の一生
#  / 花样奇缘(港)  /  令人讨厌的松子的一生(台), 评分: 8.9
# 电影名称: 蝙蝠侠：黑暗骑士崛起
#  / The Dark Knight Rises
#  / 蝙蝠侠前传3：黑暗骑士崛起  /  黑暗骑士：黎明升起(台), 评分: 8.9
# 电影名称: 爱在黎明破晓前
#  / Before Sunrise
#  / 情留半天(港)  /  爱在黎明破晓时(台), 评分: 8.8
# 电影名称: 请以你的名字呼唤我
#  / Call Me by Your Name
#  / 以你的名字呼唤我(港 / 台), 评分: 8.8
# 电影名称: 甜蜜蜜
#  / Comrades: Almost a Love Story, 评分: 8.9
# 电影名称: 断背山
#  / Brokeback Mountain
#  / 断臂山  /  BBM, 评分: 8.8
# 电影名称: 剪刀手爱德华
#  / Edward Scissorhands
#  / 幻海奇缘(港)  /  剪刀手爱德华, 评分: 8.7
# 电影名称: 入殓师
#  / おくりびと
#  / 礼仪师之奏鸣曲(港)  /  礼仪师(台), 评分: 8.9
# 电影名称: 第六感
#  / The Sixth Sense
#  / 鬼眼(港)  /  灵异第六感(台), 评分: 8.9
# 电影名称: 重庆森林
#  / 重慶森林
#  / Chungking Express, 评分: 8.8
# 电影名称: 超能陆战队
#  / Big Hero 6
#  / 大英雄联盟(港)  /  大英雄天团(台), 评分: 8.7
# 电影名称: 勇敢的心
#  / Braveheart
#  / 惊世未了缘(港)  /  梅尔吉勃逊之英雄本色(台), 评分: 8.9
# 电影名称: 爱在日落黄昏时
#  / Before Sunset
#  / 日落巴黎(港)  /  爱在日落巴黎时(台), 评分: 8.9
# 电影名称: 幽灵公主
#  / もののけ姫
#  / 魔法公主(港)  /  魔法公主(台), 评分: 8.9
# 电影名称: 菊次郎的夏天
#  / 菊次郎の夏
#  / 菊次郎之夏  /  Kikujirô no natsu, 评分: 8.9
# 电影名称: 寄生虫
#  / 기생충
#  / 寄生上流(台)  /  上流寄生族(港), 评分: 8.8
# 电影名称: 借东西的小人阿莉埃蒂
#  / 借りぐらしのアリエッティ
#  / 借物少女艾莉缇(台)  /  借东西的小矮人亚莉亚蒂(港), 评分: 8.9
# 电影名称: 消失的爱人
#  / Gone Girl
#  / 失踪的女孩  /  失踪女孩, 评分: 8.7
# 电影名称: 无人知晓
#  / 誰も知らない
#  / 谁知赤子心(港)  /  无人知晓的夏日清晨(台), 评分: 9.1
# 电影名称: 阳光灿烂的日子
#  / In the Heat of the Sun, 评分: 8.8
# 电影名称: 完美的世界
#  / A Perfect World
#  / 强盗保镳, 评分: 9.1
# 电影名称: 天使爱美丽
#  / Le fabuleux destin d'Amélie Poulain
#  / 艾蜜莉的异想世界(台)  /  天使艾米莉, 评分: 8.7
# 电影名称: 倩女幽魂
#  / 倩女幽魂(87版)  /  倩女幽魂：妖魔道, 评分: 8.8
# 电影名称: 时空恋旅人
#  / About Time
#  / 回到最爱的一天(港)  /  真爱每一天(台), 评分: 8.8
# 电影名称: 小森林 夏秋篇
#  / リトル・フォレスト 夏・秋
#  / 小森食光 / 夏秋篇(台), 评分: 9.0
# 电影名称: 未麻的部屋
#  / Perfect Blue
#  / 蓝色恐惧(港 / 台), 评分: 9.1
# 电影名称: 哈利·波特与火焰杯
#  / Harry Potter and the Goblet of Fire
#  / 哈利波特4：火杯的考验(港 / 台), 评分: 8.8
# 电影名称: 侧耳倾听
#  / 耳をすませば
#  / 心之谷(台)  /  梦幻街少女(港), 评分: 8.9
# 电影名称: 驯龙高手
#  / How to Train Your Dragon
#  / 驯龙记(港), 评分: 8.8
# 电影名称: 幸福终点站
#  / The Terminal
#  / 机场客运站(港)  /  航站情缘(台), 评分: 8.8
# 电影名称: 一个叫欧维的男人决定去死
#  / En man som heter Ove
#  / 明天别再来敲门(台)  /  想死冇咁易(港), 评分: 8.9
# 电影名称: 怪兽电力公司
#  / Monsters, Inc.
#  / 怪兽公司(港)  /  怪物公司, 评分: 8.8
# 电影名称: 教父3
#  / The Godfather: Part III
#  / 教父第三集  /  教父 III, 评分: 9.0
# 电影名称: 小森林 冬春篇
#  / リトル・フォレスト 冬・春
#  / 小森食光 / 冬春篇(台), 评分: 9.0
# 电影名称: 玩具总动员3
#  / Toy Story 3
#  / 反斗奇兵3(港)  /  玩具的故事3, 评分: 8.9
# 电影名称: 傲慢与偏见
#  / Pride & Prejudice
#  / 傲慢与偏见2005  /  Pride And Prejudice, 评分: 8.7
# 电影名称: 新世界
#  / 신세계
#  / 暗黑新世界(台)  /  New World, 评分: 8.9
# 电影名称: 茶馆
#  / The Teahouse, 评分: 9.6
# 电影名称: 萤火之森
#  / 蛍火の杜へ
#  / 萤火之社  /  Hotarubi no mori e, 评分: 8.9
# 电影名称: 釜山行
#  / 부산행
#  / 尸杀列车(港)  /  尸速列车(台), 评分: 8.6
# 电影名称: 被解救的姜戈
#  / Django Unchained
#  / 被解放的姜戈  /  决杀令(台), 评分: 8.8
# 电影名称: 神偷奶爸
#  / Despicable Me
#  / 卑鄙的我  /  坏蛋奖门人(港), 评分: 8.7
# 电影名称: 色，戒
#  / 色|戒  /  色·戒, 评分: 8.7
# 电影名称: 告白
#  / 自白  /  母亲, 评分: 8.8
# 电影名称: 哪吒闹海
#  / Prince Nezha's Triumph Against Dragon King  /  Nezha Conquers the Dragon King, 评分: 9.2
# 电影名称: 玛丽和马克思
#  / Mary and Max
#  / 巧克力情缘(台)  /  同是天涯寂寞客, 评分: 9.0
# 电影名称: 九品芝麻官
#  / 九品芝麻官之白面包青天  /  Hail the Judge, 评分: 8.7
# 电影名称: 大鱼
#  / Big Fish
#  / 大鱼奇缘(港)  /  大智若鱼(台), 评分: 8.8
# 电影名称: 喜宴
#  / 囍宴
#  / The Wedding Banquet, 评分: 9.0
# 电影名称: 模仿游戏
#  / The Imitation Game
#  / 解码游戏(港)  /  模拟游戏, 评分: 8.8
# 电影名称: 头号玩家
#  / Ready Player One
#  / 玩家一号  /  挑战者1号(港), 评分: 8.6
# 电影名称: 花样年华
#  / 花樣年華
#  / In the Mood for Love, 评分: 8.8
# 电影名称: 头脑特工队
#  / Inside Out
#  / 玩转脑朋友(港)  /  脑筋急转弯(台), 评分: 8.8
# 电影名称: 射雕英雄传之东成西就
#  / 射鵰英雄傳之東成西就
#  / 东成西就  /  大英雄 (日本), 评分: 8.7
# 电影名称: 我是山姆
#  / I Am Sam
#  / 不一样的爸爸(港)  /  他不笨，他是我爸爸(台), 评分: 9.0
# 电影名称: 七武士
#  / 七人の侍
#  / 七侠四义(港)  /  七剑客(港), 评分: 9.3
# 电影名称: 阳光姐妹淘
#  / 써니
#  / 阳光姊妹淘(港)  /  桑尼, 评分: 8.8
# 电影名称: 血战钢锯岭
#  / Hacksaw Ridge
#  / 钢锯岭  /  钢铁英雄(台), 评分: 8.7
# 电影名称: 惊魂记
#  / Psycho
#  / 精神病患者  /  触目惊心(港), 评分: 9.0
# 电影名称: 恐怖直播
#  / 더 테러 라이브
#  / 死亡“动”新闻(港)  /  恐怖攻击直播(台), 评分: 8.7
# 电影名称: 黑客帝国3：矩阵革命
#  / The Matrix Revolutions
#  / 22世纪杀人网络3：惊变世纪(港)  /  骇客任务完结篇：最后战役(台), 评分: 8.8
# 电影名称: 你的名字。
#  / 君の名は。
#  / 你的名字  /  君之名, 评分: 8.5
# 电影名称: 三块广告牌
#  / Three Billboards Outside Ebbing, Missouri
#  / 广告牌杀人事件(港)  /  意外(台), 评分: 8.7
# 电影名称: 电锯惊魂
#  / Saw
#  / 恐惧斗室(港)  /  夺魂锯(台), 评分: 8.7
# 电影名称: 心迷宫
#  / 殡棺  /  The Coffin in the Mountain, 评分: 8.7
# 电影名称: 达拉斯买家俱乐部
#  / Dallas Buyers Club
#  / 续命枭雄(港)  /  药命俱乐部(台), 评分: 8.8
# 电影名称: 疯狂原始人
#  / The Croods
#  / 古鲁家族(港 / 台), 评分: 8.7
# 电影名称: 谍影重重3
#  / The Bourne Ultimatum
#  / 叛谍追击3：最后通牒(港)  /  神鬼认证：最后通牒 (台), 评分: 8.8
# 电影名称: 英雄本色
#  / A Better Tomorrow  /  Gangland Boss, 评分: 8.6
# 电影名称: 上帝之城
#  / Cidade de Deus
#  / 无主之城(港)  /  无法无天(台), 评分: 9.0
# 电影名称: 小丑
#  / Joker
#  / 小丑起源电影：罗密欧  /  Romeo, 评分: 8.7
# 电影名称: 风之谷
#  / 風の谷のナウシカ
#  / 风谷少女  /  Kaze no tani no Naushika, 评分: 8.9
# 电影名称: 绿里奇迹
#  / The Green Mile
#  / 绿色奇迹(台)  /  绿色英里, 评分: 8.9
# 电影名称: 爱在午夜降临前
#  / Before Midnight
#  / 情约半生(港)  /  爱在午夜希腊时(台), 评分: 8.9
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 小鞋子
#  / بچه های آسمان
#  / 天堂的孩子  /  小童鞋, 评分: 9.2
# 电影名称: 沉默的羔羊
#  / The Silence of the Lambs
#  / 沉默的羔羊, 评分: 8.9
# 电影名称: 功夫
#  / 功夫3D  /  Kung Fu Hustle, 评分: 8.8
# 电影名称: 布达佩斯大饭店
#  / The Grand Budapest Hotel
#  / 布达佩斯大酒店(港)  /  欢迎来到布达佩斯大饭店(台), 评分: 8.9
# 电影名称: 禁闭岛
#  / Shutter Island
#  / 不赦岛(港)  /  隔离岛(台), 评分: 8.9
# 电影名称: 蝴蝶效应
#  / The Butterfly Effect
#  / 蝴蝶效应, 评分: 8.9
# 电影名称: 哈利·波特与阿兹卡班的囚徒
#  / Harry Potter and the Prisoner of Azkaban
#  / 哈利波特3：阿兹卡班的逃犯(港 / 台), 评分: 9.0
# 电影名称: 致命魔术
# ...
# 电影名称: 人工智能
#  / A.I. Artificial Intelligence
#  / AI人工智慧, 评分: 8.7
# 电影名称: 爱乐之城
#  / La La Land
#  / 星声梦里人(港)  /  乐来越爱你(台), 评分: 8.4
# 电影名称: 恋恋笔记本
#  / The Notebook
#  / 忘了·忘不了(港)  /  手札情缘(台), 评分: 8.5
# 电影名称: 终结者2：审判日
#  / Terminator 2: Judgment Day
#  / 未来战士2(港)  /  魔鬼终结者2(台), 评分: 8.8
# 电影名称: 虎口脱险
#  / La grande vadrouille
#  / 横冲直撞出重围(港)  /  大進擊(台), 评分: 8.9
# 电影名称: 疯狂的麦克斯4：狂暴之路
#  / Mad Max: Fury Road
#  / 末日先锋：战甲飞车(港)  /  疯狂麦斯：愤怒道(台), 评分: 8.7
# 电影名称: 芙蓉镇
#  / Hibiscus Town, 评分: 9.3
# 电影名称: 罗生门
#  / 羅生門
#  / Rashomon, 评分: 8.8
# 电影名称: 新龙门客栈
#  / 新龍門客棧
#  / New Dragon Gate Inn, 评分: 8.7
# 电影名称: 无耻混蛋
#  / Inglourious Basterds
#  / 希魔撞正杀人狂(港)  /  恶棍特工(台), 评分: 8.7
# 电影名称: 崖上的波妞
#  / 崖の上のポニョ
#  / 悬崖上的金鱼姬  /  悬崖上的金鱼公主, 评分: 8.6
# 电影名称: 千钧一发
#  / Gattaca
#  / 变种异煞(港)  /  自然人, 评分: 8.8
# 电影名称: 花束般的恋爱
#  / 花束みたいな恋をした
#  / 她和他的恋爱花期(港)  /  爱如花束 恋恋不忘, 评分: 8.6
# 电影名称: 肖申克的救赎
#  / The Shawshank Redemption
#  / 月黑高飞(港)  /  刺激1995(台), 评分: 9.7
# 电影名称: 霸王别姬
#  / 再见，我的妾  /  Farewell My Concubine, 评分: 9.6
# 电影名称: 阿甘正传
#  / Forrest Gump
#  / 福雷斯特·冈普, 评分: 9.5
# 电影名称: 泰坦尼克号
#  / Titanic
#  / 铁达尼号(港 / 台), 评分: 9.5
# 电影名称: 千与千寻
#  / 千と千尋の神隠し
#  / 神隐少女(台)  /  千与千寻的神隐, 评分: 9.4
# 电影名称: 这个杀手不太冷
#  / Léon
#  / 终极追杀令(台)  /  杀手莱昂, 评分: 9.4
# 电影名称: 美丽人生
#  / La vita è bella
#  / 一个快乐的传说(港)  /  Life Is Beautiful, 评分: 9.5
# 电影名称: 星际穿越
#  / Interstellar
#  / 星际启示录(港)  /  星际效应(台), 评分: 9.4
# 电影名称: 盗梦空间
#  / Inception
#  / 潜行凶间(港)  /  全面启动(台), 评分: 9.4
# 电影名称: 辛德勒的名单
#  / Schindler's List
#  / 舒特拉的名单(港)  /  辛德勒名单, 评分: 9.5
# 电影名称: 楚门的世界
#  / The Truman Show
#  / 真人Show(港)  /  真人戏, 评分: 9.4
# 电影名称: 忠犬八公的故事
#  / Hachi: A Dog's Tale
#  / 秋田犬八千(港)  /  忠犬小八(台), 评分: 9.4
# 电影名称: 海上钢琴师
#  / La leggenda del pianista sull'oceano
#  / 声光伴我飞(港)  /  一九零零的传奇, 评分: 9.3
# 电影名称: 三傻大闹宝莱坞
#  / 3 Idiots
#  / 三个傻瓜(台)  /  作死不离3兄弟(港), 评分: 9.2
# 电影名称: 放牛班的春天
#  / Les choristes
#  / 歌声伴我心(港)  /  唱诗班男孩, 评分: 9.3
# 电影名称: 机器人总动员
#  / WALL·E
#  / 太空奇兵·威E(港)  /  瓦力(台), 评分: 9.3
# 电影名称: 疯狂动物城
#  / Zootopia
#  / 优兽大都会(港)  /  动物方城市(台), 评分: 9.2
# 电影名称: 无间道
#  / 無間道
#  / Infernal Affairs  /  Mou gaan dou, 评分: 9.3
# 电影名称: 控方证人
#  / Witness for the Prosecution
#  / 雄才伟略  /  情妇, 评分: 9.6
# 电影名称: 大话西游之大圣娶亲
#  / 西遊記大結局之仙履奇緣
#  / 西游记完结篇仙履奇缘  /  齐天大圣西游记, 评分: 9.2
# 电影名称: 熔炉
#  / 도가니
#  / 无声呐喊(港)  /  漩涡, 评分: 9.4
# 电影名称: 教父
#  / The Godfather
#  / Mario Puzo's The Godfather, 评分: 9.3
# 电影名称: 触不可及
#  / Intouchables
#  / 闪亮人生(港)  /  逆转人生(台), 评分: 9.3
# 电影名称: 当幸福来敲门
#  / The Pursuit of Happyness
#  / 寻找快乐的故事(港)  /  追求快乐, 评分: 9.2
# 电影名称: 寻梦环游记
#  / Coco
#  / 玩转极乐园(港)  /  可可夜总会(台), 评分: 9.1
# 电影名称: 末代皇帝
#  / The Last Emperor
#  / 末代皇帝溥仪(港)  /  L'ultimo imperatore, 评分: 9.3
# 电影名称: 龙猫
#  / となりのトトロ
#  / 邻居托托罗  /  邻家的豆豆龙, 评分: 9.2
# 电影名称: 怦然心动
#  / Flipped
#  / 萌动青春  /  青春萌动, 评分: 9.1
# 电影名称: 活着
#  / 人生  /  Lifetimes, 评分: 9.3
# 电影名称: 哈利·波特与魔法石
#  / Harry Potter and the Sorcerer's Stone
#  / 哈利波特1：神秘的魔法石(港 / 台), 评分: 9.2
# 电影名称: 蝙蝠侠：黑暗骑士
#  / The Dark Knight
#  / 蝙蝠侠前传2：黑暗骑士  /  黑暗骑士(台), 评分: 9.2
# 电影名称: 指环王3：王者无敌
#  / The Lord of the Rings: The Return of the King
#  / 魔戒三部曲：王者再临(台 / 港), 评分: 9.3
# 电影名称: 我不是药神
#  / 中国药神  /  印度药神, 评分: 9.0
# 电影名称: 乱世佳人
#  / Gone with the Wind
#  / 飘, 评分: 9.3
# 电影名称: 飞屋环游记
#  / Up
#  / 冲天救兵(港)  /  天外奇迹(台), 评分: 9.1
# 电影名称: 素媛
#  / 소원
#  / 许愿  /  希望：为爱重生(台), 评分: 9.3
# 电影名称: 十二怒汉
#  / 12 Angry Men
#  / 12怒汉  /  十二怒汉, 评分: 9.4
# 电影名称: 哈尔的移动城堡
#  / ハウルの動く城
#  / 哈尔移动城堡(港)  /  霍尔的移动城堡(台), 评分: 9.1
# 电影名称: 让子弹飞
#  / 让子弹飞一会儿  /  火烧云, 评分: 9.0
# 电影名称: 何以为家
#  / كفرناحوم
#  / 迦百农  /  星仔打官司(港), 评分: 9.1
# 电影名称: 摔跤吧！爸爸
#  / Dangal
#  / 我和我的冠军女儿(台)  /  打死不离3父女(港), 评分: 9.0
# 电影名称: 猫鼠游戏
#  / Catch Me If You Can
#  / 逍遥法外  /  捉智双雄(港), 评分: 9.1
# 电影名称: 天空之城
#  / 天空の城ラピュタ
#  / 天空之城拉普他  /  空中城堡拉普他, 评分: 9.2
# 电影名称: 鬼子来了
#  / Devils on the Doorstep, 评分: 9.3
# 电影名称: 海蒂和爷爷
#  / Heidi
#  / 飘零燕(港)  /  海蒂, 评分: 9.3
# 电影名称: 少年派的奇幻漂流
#  / Life of Pi
#  / 少年Pi的奇幻漂流  /  漂流少年Pi, 评分: 9.1
# 电影名称: 钢琴家
#  / The Pianist
#  / 钢琴战曲(港)  /  战地琴人(台), 评分: 9.3
# 电影名称: 大话西游之月光宝盒
#  / 西遊記第壹佰零壹回之月光寶盒
#  / 西游记101回月光宝盒  /  齐天大圣东游记, 评分: 9.0
# 电影名称: 指环王2：双塔奇兵
#  / The Lord of the Rings: The Two Towers
#  / 魔戒二部曲：双城奇谋  /  指环王II：双塔, 评分: 9.2
# 电影名称: 闻香识女人
#  / Scent of a Woman
#  / 女人香  /  女人的芳香, 评分: 9.1
# 电影名称: 死亡诗社
#  / Dead Poets Society
#  / 暴雨骄阳(港)  /  春风化雨(台), 评分: 9.2
# 电影名称: 绿皮书
#  / Green Book
#  / 绿簿旅友(港)  /  幸福绿皮书(台), 评分: 8.9
# 电影名称: 罗马假日
#  / Roman Holiday
#  / 金枝玉叶(港)  /  罗马假期(台), 评分: 9.1
# 电影名称: 大闹天宫
#  / 大闹天宫 上下集  /  The Monkey King, 评分: 9.4
# 电影名称: 天堂电影院
#  / Nuovo Cinema Paradiso
#  / 星光伴我心(港)  /  新天堂乐园(台), 评分: 9.2
# 电影名称: 黑客帝国
#  / The Matrix
#  / 22世纪杀人网络(港)  /  廿二世纪杀人网络(港), 评分: 9.1
# 电影名称: 指环王1：护戒使者
#  / The Lord of the Rings: The Fellowship of the Ring
#  / 指环王1：魔戒再现  /  指环王I：护戒使者, 评分: 9.1
# 电影名称: 教父2
#  / The Godfather: Part II
#  / 教父续集(港)  /  教父II, 评分: 9.3
# 电影名称: 狮子王
#  / The Lion King
#  / 狮子王3D, 评分: 9.1
# 电影名称: 辩护人
#  / 변호인
#  / 逆权大状(港)  /  正义辩护人(台), 评分: 9.2
# 电影名称: 饮食男女
#  / 飲食男女
#  / Eat Drink Man Woman, 评分: 9.2
# 电影名称: 搏击俱乐部
#  / Fight Club
#  / 搏击会(港)  /  斗阵俱乐部(台), 评分: 9.0
# 电影名称: 本杰明·巴顿奇事
#  / The Curious Case of Benjamin Button
#  / 奇幻逆缘(港)  /  班杰明的奇幻旅程(台), 评分: 9.0
# 电影名称: 美丽心灵
#  / A Beautiful Mind
#  / 有你终生美丽(港)  /  美丽境界(台), 评分: 9.1
# 电影名称: 穿条纹睡衣的男孩
#  / The Boy in the Striped Pajamas
#  / 穿条纹衣服的男孩  /  穿条纹衣的男孩, 评分: 9.2
# 电影名称: 窃听风暴
#  / Das Leben der Anderen
#  / 窃听者(港)  /  他人的生活, 评分: 9.2
# 电影名称: 情书
#  / Love Letter
#  / When I Close My Eyes  /  Letters of Love, 评分: 8.9
# 电影名称: 两杆大烟枪
#  / Lock, Stock and Two Smoking Barrels
#  / 够姜四小强(港)  /  两根枪管(台), 评分: 9.1
# 电影名称: 西西里的美丽传说
#  / Malèna
#  / 真爱伴我行(台)  /  玛莲娜, 评分: 8.9
# 电影名称: 音乐之声
#  / The Sound of Music
#  / 仙乐飘飘处处闻(港)  /  真善美(台), 评分: 9.1
# 电影名称: 看不见的客人
#  / Contratiempo
#  / 死无对证(港)  /  布局(台), 评分: 8.8
# 电影名称: 阿凡达
#  / Avatar
#  /, 评分: 8.8
# 电影名称: 哈利·波特与死亡圣器(下)
#  / Harry Potter and the Deathly Hallows: Part 2
#  / 哈利波特7：死神的圣物2(港 / 台), 评分: 9.0
# 电影名称: 拯救大兵瑞恩
#  / Saving Private Ryan
#  / 雷霆救兵(港)  /  抢救雷恩大兵(台), 评分: 9.1
# 电影名称: 飞越疯人院
#  / One Flew Over the Cuckoo's Nest
#  / 飞越杜鹃窝(台)  /  飞越喜鹊巢, 评分: 9.1
# 电影名称: 小鞋子
#  / بچه های آسمان
#  / 天堂的孩子  /  小童鞋, 评分: 9.2
# 电影名称: 沉默的羔羊
#  / The Silence of the Lambs
#  / 沉默的羔羊, 评分: 8.9
# 电影名称: 功夫
#  / 功夫3D  /  Kung Fu Hustle, 评分: 8.8
# 电影名称: 布达佩斯大饭店
#  / The Grand Budapest Hotel
#  / 布达佩斯大酒店(港)  /  欢迎来到布达佩斯大饭店(台), 评分: 8.9
# 电影名称: 禁闭岛
#  / Shutter Island
#  / 不赦岛(港)  /  隔离岛(台), 评分: 8.9
# 电影名称: 蝴蝶效应
#  / The Butterfly Effect
#  / 蝴蝶效应, 评分: 8.9
# 电影名称: 哈利·波特与阿兹卡班的囚徒
#  / Harry Potter and the Prisoner of Azkaban
#  / 哈利波特3：阿兹卡班的逃犯(港 / 台), 评分: 9.0
# 电影名称: 致命魔术
#  / The Prestige
#  / 死亡魔法(港)  /  顶尖对决(台), 评分: 8.9
# 电影名称: 心灵捕手
#  / Good Will Hunting
#  / 骄阳似我(港)  /  心灵捕手, 评分: 8.9
# 电影名称: 超脱
#  / Detachment
#  / 人间师格(台), 评分: 9.0
# 电影名称: 低俗小说
#  / Pulp Fiction
#  / 危险人物(港)  /  黑色追缉令(台), 评分: 8.9
# 电影名称: 摩登时代
#  / Modern Times
#  / The Masses  /  Les Temps modernes, 评分: 9.3
# 电影名称: 海豚湾
#  / The Cove
#  / 血色海湾(台)  /  海湾, 评分: 9.3
# 电影名称: 春光乍泄
#  / 春光乍洩
#  / 一起快乐  /  Happy Together, 评分: 9.0
# 电影名称: 喜剧之王
#  / 喜劇之王
#  / King of Comedy, 评分: 8.8
# 电影名称: 美国往事
#  / Once Upon a Time in America
#  / 四海兄弟(台)  /  义薄云天(港), 评分: 9.2
# 电影名称: 致命ID
#  / Identity
#  / 杀人游戏  /  致命身份, 评分: 8.9
# 电影名称: 杀人回忆
#  / 살인의 추억
#  / 谋杀回忆  /  杀手回忆录, 评分: 8.9
# 电影名称: 哈利·波特与密室
#  / Harry Potter and the Chamber of Secrets
#  / 哈利波特2：消失的密室(港 / 台), 评分: 8.9
# 电影名称: 红辣椒
#  / パプリカ
#  / 盗梦侦探(港 / 台), 评分: 9.1
# 电影名称: 七宗罪
#  / Se7en
#  / 火线追缉令(台)  /  7宗罪, 评分: 8.8
# 电影名称: 加勒比海盗
#  / Pirates of the Caribbean: The Curse of the Black Pearl
#  / 加勒比海盗1：黑珍珠号的诅咒  /  神鬼奇航：鬼盗船魔咒(台), 评分: 8.8
# 电影名称: 一一
#  / Yi yi  /  Yi yi: A One and a Two, 评分: 9.1
# 电影名称: 狩猎
#  / Jagten
#  / 诬网(港)  /  谎言的烙印(台), 评分: 9.1
# 电影名称: 唐伯虎点秋香
#  / 唐伯虎點秋香
#  / Flirting Scholar, 评分: 8.7
# 电影名称: 7号房的礼物
#  / 7번방의 선물
#  / 戆爸的礼物(港)  /  7号囚房的礼物, 评分: 8.9
# 电影名称: 被嫌弃的松子的一生
#  / 嫌われ松子の一生
#  / 花样奇缘(港)  /  令人讨厌的松子的一生(台), 评分: 8.9
# 电影名称: 蝙蝠侠：黑暗骑士崛起
#  / The Dark Knight Rises
#  / 蝙蝠侠前传3：黑暗骑士崛起  /  黑暗骑士：黎明升起(台), 评分: 8.9
# 电影名称: 爱在黎明破晓前
#  / Before Sunrise
#  / 情留半天(港)  /  爱在黎明破晓时(台), 评分: 8.8
# 电影名称: 请以你的名字呼唤我
#  / Call Me by Your Name
#  / 以你的名字呼唤我(港 / 台), 评分: 8.8
# 电影名称: 甜蜜蜜
#  / Comrades: Almost a Love Story, 评分: 8.9
# 电影名称: 断背山
#  / Brokeback Mountain
#  / 断臂山  /  BBM, 评分: 8.8
# 电影名称: 剪刀手爱德华
#  / Edward Scissorhands
#  / 幻海奇缘(港)  /  剪刀手爱德华, 评分: 8.7
# 电影名称: 入殓师
#  / おくりびと
#  / 礼仪师之奏鸣曲(港)  /  礼仪师(台), 评分: 8.9
# 电影名称: 第六感
#  / The Sixth Sense
#  / 鬼眼(港)  /  灵异第六感(台), 评分: 8.9
# 电影名称: 重庆森林
#  / 重慶森林
#  / Chungking Express, 评分: 8.8
# 电影名称: 超能陆战队
#  / Big Hero 6
#  / 大英雄联盟(港)  /  大英雄天团(台), 评分: 8.7
# 电影名称: 勇敢的心
#  / Braveheart
#  / 惊世未了缘(港)  /  梅尔吉勃逊之英雄本色(台), 评分: 8.9
# 电影名称: 爱在日落黄昏时
#  / Before Sunset
#  / 日落巴黎(港)  /  爱在日落巴黎时(台), 评分: 8.9
# 电影名称: 幽灵公主
#  / もののけ姫
#  / 魔法公主(港)  /  魔法公主(台), 评分: 8.9
# 电影名称: 菊次郎的夏天
#  / 菊次郎の夏
#  / 菊次郎之夏  /  Kikujirô no natsu, 评分: 8.9
# 电影名称: 寄生虫
#  / 기생충
#  / 寄生上流(台)  /  上流寄生族(港), 评分: 8.8
# 电影名称: 借东西的小人阿莉埃蒂
#  / 借りぐらしのアリエッティ
#  / 借物少女艾莉缇(台)  /  借东西的小矮人亚莉亚蒂(港), 评分: 8.9
# 电影名称: 消失的爱人
#  / Gone Girl
#  / 失踪的女孩  /  失踪女孩, 评分: 8.7
# 电影名称: 无人知晓
#  / 誰も知らない
#  / 谁知赤子心(港)  /  无人知晓的夏日清晨(台), 评分: 9.1
# 电影名称: 阳光灿烂的日子
#  / In the Heat of the Sun, 评分: 8.8
# 电影名称: 完美的世界
#  / A Perfect World
#  / 强盗保镳, 评分: 9.1
# 电影名称: 天使爱美丽
#  / Le fabuleux destin d'Amélie Poulain
#  / 艾蜜莉的异想世界(台)  /  天使艾米莉, 评分: 8.7
# 电影名称: 倩女幽魂
#  / 倩女幽魂(87版)  /  倩女幽魂：妖魔道, 评分: 8.8
# 电影名称: 时空恋旅人
#  / About Time
#  / 回到最爱的一天(港)  /  真爱每一天(台), 评分: 8.8
# 电影名称: 小森林 夏秋篇
#  / リトル・フォレスト 夏・秋
#  / 小森食光 / 夏秋篇(台), 评分: 9.0
# 电影名称: 未麻的部屋
#  / Perfect Blue
#  / 蓝色恐惧(港 / 台), 评分: 9.1
# 电影名称: 哈利·波特与火焰杯
#  / Harry Potter and the Goblet of Fire
#  / 哈利波特4：火杯的考验(港 / 台), 评分: 8.8
# 电影名称: 侧耳倾听
#  / 耳をすませば
#  / 心之谷(台)  /  梦幻街少女(港), 评分: 8.9
# 电影名称: 驯龙高手
#  / How to Train Your Dragon
#  / 驯龙记(港), 评分: 8.8
# 电影名称: 幸福终点站
#  / The Terminal
#  / 机场客运站(港)  /  航站情缘(台), 评分: 8.8
# 电影名称: 一个叫欧维的男人决定去死
#  / En man som heter Ove
#  / 明天别再来敲门(台)  /  想死冇咁易(港), 评分: 8.9
# 电影名称: 怪兽电力公司
#  / Monsters, Inc.
#  / 怪兽公司(港)  /  怪物公司, 评分: 8.8
# 电影名称: 教父3
#  / The Godfather: Part III
#  / 教父第三集  /  教父 III, 评分: 9.0
# 电影名称: 小森林 冬春篇
#  / リトル・フォレスト 冬・春
#  / 小森食光 / 冬春篇(台), 评分: 9.0
# 电影名称: 玩具总动员3
#  / Toy Story 3
#  / 反斗奇兵3(港)  /  玩具的故事3, 评分: 8.9
# 电影名称: 傲慢与偏见
#  / Pride & Prejudice
#  / 傲慢与偏见2005  /  Pride And Prejudice, 评分: 8.7
# 电影名称: 新世界
#  / 신세계
#  / 暗黑新世界(台)  /  New World, 评分: 8.9
# 电影名称: 茶馆
#  / The Teahouse, 评分: 9.6
# 电影名称: 萤火之森
#  / 蛍火の杜へ
#  / 萤火之社  /  Hotarubi no mori e, 评分: 8.9
# 电影名称: 釜山行
#  / 부산행
#  / 尸杀列车(港)  /  尸速列车(台), 评分: 8.6
# 电影名称: 被解救的姜戈
#  / Django Unchained
#  / 被解放的姜戈  /  决杀令(台), 评分: 8.8
# 电影名称: 神偷奶爸
#  / Despicable Me
#  / 卑鄙的我  /  坏蛋奖门人(港), 评分: 8.7
# 电影名称: 色，戒
#  / 色|戒  /  色·戒, 评分: 8.7
# 电影名称: 告白
#  / 自白  /  母亲, 评分: 8.8
# 电影名称: 哪吒闹海
#  / Prince Nezha's Triumph Against Dragon King  /  Nezha Conquers the Dragon King, 评分: 9.2
# 电影名称: 玛丽和马克思
#  / Mary and Max
#  / 巧克力情缘(台)  /  同是天涯寂寞客, 评分: 9.0
# 电影名称: 九品芝麻官
#  / 九品芝麻官之白面包青天  /  Hail the Judge, 评分: 8.7
# 电影名称: 大鱼
#  / Big Fish
#  / 大鱼奇缘(港)  /  大智若鱼(台), 评分: 8.8
# 电影名称: 喜宴
#  / 囍宴
#  / The Wedding Banquet, 评分: 9.0
# 电影名称: 模仿游戏
#  / The Imitation Game
#  / 解码游戏(港)  /  模拟游戏, 评分: 8.8
# 电影名称: 头号玩家
#  / Ready Player One
#  / 玩家一号  /  挑战者1号(港), 评分: 8.6
# 电影名称: 花样年华
#  / 花樣年華
#  / In the Mood for Love, 评分: 8.8
# 电影名称: 头脑特工队
#  / Inside Out
#  / 玩转脑朋友(港)  /  脑筋急转弯(台), 评分: 8.8
# 电影名称: 射雕英雄传之东成西就
#  / 射鵰英雄傳之東成西就
#  / 东成西就  /  大英雄 (日本), 评分: 8.7
# 电影名称: 我是山姆
#  / I Am Sam
#  / 不一样的爸爸(港)  /  他不笨，他是我爸爸(台), 评分: 9.0
# 电影名称: 七武士
#  / 七人の侍
#  / 七侠四义(港)  /  七剑客(港), 评分: 9.3
# 电影名称: 阳光姐妹淘
#  / 써니
#  / 阳光姊妹淘(港)  /  桑尼, 评分: 8.8
# 电影名称: 血战钢锯岭
#  / Hacksaw Ridge
#  / 钢锯岭  /  钢铁英雄(台), 评分: 8.7
# 电影名称: 惊魂记
#  / Psycho
#  / 精神病患者  /  触目惊心(港), 评分: 9.0
# 电影名称: 恐怖直播
#  / 더 테러 라이브
#  / 死亡“动”新闻(港)  /  恐怖攻击直播(台), 评分: 8.7
# 电影名称: 黑客帝国3：矩阵革命
#  / The Matrix Revolutions
#  / 22世纪杀人网络3：惊变世纪(港)  /  骇客任务完结篇：最后战役(台), 评分: 8.8
# 电影名称: 你的名字。
#  / 君の名は。
#  / 你的名字  /  君之名, 评分: 8.5
# 电影名称: 三块广告牌
#  / Three Billboards Outside Ebbing, Missouri
#  / 广告牌杀人事件(港)  /  意外(台), 评分: 8.7
# 电影名称: 电锯惊魂
#  / Saw
#  / 恐惧斗室(港)  /  夺魂锯(台), 评分: 8.7
# 电影名称: 心迷宫
#  / 殡棺  /  The Coffin in the Mountain, 评分: 8.7
# 电影名称: 达拉斯买家俱乐部
#  / Dallas Buyers Club
#  / 续命枭雄(港)  /  药命俱乐部(台), 评分: 8.8
# 电影名称: 疯狂原始人
#  / The Croods
#  / 古鲁家族(港 / 台), 评分: 8.7
# 电影名称: 谍影重重3
#  / The Bourne Ultimatum
#  / 叛谍追击3：最后通牒(港)  /  神鬼认证：最后通牒 (台), 评分: 8.8
# 电影名称: 英雄本色
#  / A Better Tomorrow  /  Gangland Boss, 评分: 8.6
# 电影名称: 上帝之城
#  / Cidade de Deus
#  / 无主之城(港)  /  无法无天(台), 评分: 9.0
# 电影名称: 小丑
#  / Joker
#  / 小丑起源电影：罗密欧  /  Romeo, 评分: 8.7
# 电影名称: 风之谷
#  / 風の谷のナウシカ
#  / 风谷少女  /  Kaze no tani no Naushika, 评分: 8.9
# 电影名称: 绿里奇迹
#  / The Green Mile
#  / 绿色奇迹(台)  /  绿色英里, 评分: 8.9
# 电影名称: 爱在午夜降临前
#  / Before Midnight
#  / 情约半生(港)  /  爱在午夜希腊时(台), 评分: 8.9
# 电影名称: 海街日记
#  / 海街diary
#  / 海街女孩日记(港)  /  Kamakura Diary, 评分: 8.8
# 电影名称: 纵横四海
#  / 緃横四海
#  / Once a Thief, 评分: 8.8
# 电影名称: 卢旺达饭店
#  / Hotel Rwanda
#  / 卢安达饭店(台), 评分: 8.9
# 电影名称: 心灵奇旅
#  / Soul
#  / 灵魂奇遇记(港)  /  灵魂急转弯(台), 评分: 8.7
# 电影名称: 背靠背，脸对脸
#  / 背对背，脸对脸  /  Back to Back, Face to Face, 评分: 9.5
# 电影名称: 记忆碎片
#  / Memento
#  / 凶心人(港)  /  记忆拼图(台), 评分: 8.7
# 电影名称: 疯狂的石头
#  / Crazy Stone, 评分: 8.6
# 电影名称: 雨中曲
#  / Singin' in the Rain
#  / 万花嬉春(港 / 台), 评分: 9.1
# 电影名称: 2001太空漫游
#  / 2001: A Space Odyssey
#  / 2001：星际漫游  /  2001：太空奥德赛, 评分: 8.9
# 电影名称: 无间道2
#  / 無間道II
#  / 无间道前传  /  Infernal Affairs II, 评分: 8.7
# 电影名称: 岁月神偷
#  / 歲月神偷
#  / 1969太空漫游  /  Echoes Of The Rainbow, 评分: 8.7
# 电影名称: 小偷家族
#  / 万引き家族
#  / Shoplifters  /  Une Affaire de Famille, 评分: 8.7
# 电影名称: 忠犬八公物语
#  / ハチ公物語
#  / 八千公物语  /  阿八的故事, 评分: 9.2
# 电影名称: 无敌破坏王
#  / Wreck-It Ralph
#  / 破坏王拉尔夫  /  破坏王大冒险, 评分: 8.7
# 电影名称: 荒蛮故事
#  / Relatos salvajes
#  / 蛮荒故事  /  生命中最抓狂的小事(台), 评分: 8.8
# 电影名称: 冰川时代
#  / Ice Age
#  / 冰河世纪  /  冰原历险记, 评分: 8.6
# 电影名称: 爆裂鼓手
#  / Whiplash
#  / 鼓动真我(港)  /  进击的鼓手(台), 评分: 8.7
# 电影名称: 恐怖游轮
#  / Triangle
#  / 汪洋血迷宮(台)  /  轮回三角, 评分: 8.5
# 电影名称: 牯岭街少年杀人事件
#  / 牯嶺街少年殺人事件
#  / A Brighter Summer Day, 评分: 8.9
# 电影名称: 东京教父
#  / 東京ゴッドファーザーズ
#  / Tokyo Godfathers, 评分: 9.0
# 电影名称: 贫民窟的百万富翁
#  / Slumdog Millionaire
#  / 一百万零一夜(港)  /  贫民百万富翁(台), 评分: 8.6
# 电影名称: 魔女宅急便
#  / 魔女の宅急便
#  / 魔女琪琪(台)  /  小魔女限时专送, 评分: 8.7
# 电影名称: 大佛普拉斯
#  / The Great Buddha+, 评分: 8.7
# 电影名称: 东邪西毒
#  / 東邪西毒
#  / Ashes of Time, 评分: 8.6
# 电影名称: 遗愿清单
#  / The Bucket List
#  / 玩转身前事(港)  /  一路玩到挂(台), 评分: 8.7
# 电影名称: 你看起来好像很好吃
#  / おまえうまそうだな
#  / 你看起来很好吃(台)  /  你看上去好像很好吃, 评分: 8.9
# 电影名称: 可可西里
#  / Kekexili: Mountain Patrol, 评分: 8.9
# 电影名称: 黑天鹅
#  / Black Swan
#  / 夺命黑天鹅  /  霸王别鹅(豆友译名), 评分: 8.6
# 电影名称: 城市之光
#  / City Lights
#  / City Lights: A Comedy Romance in Pantomime  /  Lichter der Großstadt, 评分: 9.3
# 电影名称: 源代码
#  / Source Code
#  / 启动原始码(台)  /  危机解密(港), 评分: 8.5
# 电影名称: 真爱至上
#  / Love Actually
#  / 真的恋爱了(港)  /  爱是您，爱是我(台), 评分: 8.5
# 电影名称: 海边的曼彻斯特
#  / Manchester by the Sea
#  / 情系海边之城(港), 评分: 8.6
# 电影名称: 末路狂花
#  / Thelma & Louise
#  / 塞尔玛与路易丝  /  末路狂花, 评分: 8.9
# 电影名称: 波西米亚狂想曲
#  / Bohemian Rhapsody
#  / 波希米亚狂想曲：摇滚传说(港)  /  波希米亚狂想曲(台), 评分: 8.6
# 电影名称: 雨人
#  / Rain Man
#  / 手足情未了(港)  /  手足情深, 评分: 8.7
# 电影名称: 青蛇
#  / Green Snake, 评分: 8.6
# 电影名称: 初恋这件小事
#  / สิ่งเล็กเล็กที่เรียกว่า...รัก
#  / 初恋那件小事(港)  /  暗恋那点小事, 评分: 8.5
# 电影名称: 人工智能
#  / A.I. Artificial Intelligence
#  / AI人工智慧, 评分: 8.7
# 电影名称: 爱乐之城
#  / La La Land
#  / 星声梦里人(港)  /  乐来越爱你(台), 评分: 8.4
# 电影名称: 恋恋笔记本
#  / The Notebook
#  / 忘了·忘不了(港)  /  手札情缘(台), 评分: 8.5
# 电影名称: 终结者2：审判日
#  / Terminator 2: Judgment Day
#  / 未来战士2(港)  /  魔鬼终结者2(台), 评分: 8.8
# 电影名称: 虎口脱险
#  / La grande vadrouille
#  / 横冲直撞出重围(港)  /  大進擊(台), 评分: 8.9
# 电影名称: 疯狂的麦克斯4：狂暴之路
#  / Mad Max: Fury Road
#  / 末日先锋：战甲飞车(港)  /  疯狂麦斯：愤怒道(台), 评分: 8.7
# 电影名称: 芙蓉镇
#  / Hibiscus Town, 评分: 9.3
# 电影名称: 罗生门
#  / 羅生門
#  / Rashomon, 评分: 8.8
# 电影名称: 新龙门客栈
#  / 新龍門客棧
#  / New Dragon Gate Inn, 评分: 8.7
# 电影名称: 无耻混蛋
#  / Inglourious Basterds
#  / 希魔撞正杀人狂(港)  /  恶棍特工(台), 评分: 8.7
# 电影名称: 崖上的波妞
#  / 崖の上のポニョ
#  / 悬崖上的金鱼姬  /  悬崖上的金鱼公主, 评分: 8.6
# 电影名称: 千钧一发
#  / Gattaca
#  / 变种异煞(港)  /  自然人, 评分: 8.8
# 电影名称: 花束般的恋爱
#  / 花束みたいな恋をした
#  / 她和他的恋爱花期(港)  /  爱如花束 恋恋不忘, 评分: 8.6
# 电影名称: 彗星来的那一夜
#  / Coherence
#  / 相干性  /  相干效应, 评分: 8.6
# 电影名称: 萤火虫之墓
#  / 火垂るの墓
#  / 再见萤火虫(港)  /  萤火挽歌, 评分: 8.7
# 电影名称: 哈利·波特与死亡圣器(上)
#  / Harry Potter and the Deathly Hallows: Part 1
#  / 哈利波特7：死神的圣物1(港 / 台), 评分: 8.5
# 电影名称: 奇迹男孩
#  / Wonder
#  / 奇迹, 评分: 8.6
# 电影名称: 黑客帝国2：重装上阵
#  / The Matrix Reloaded
#  / 22世纪杀人网络2：决战未来(港)  /  骇客任务：重装上阵(台), 评分: 8.7
# 电影名称: 二十二
#  / Twenty Two  /  22, 评分: 8.7
# 电影名称: 火星救援
#  / The Martian
#  / 火星任务(港)  /  绝地救援(台), 评分: 8.5
# 电影名称: 白日梦想家
#  / The Secret Life of Walter Mitty
#  / 发梦王大历险(港)  /  白日梦冒险王(台), 评分: 8.6
# 电影名称: 战争之王
#  / Lord of War
#  / 军火之王(台 / 港), 评分: 8.7
# 电影名称: 血钻
#  / Blood Diamond
#  / 血钻石(台)  /  血腥钻石, 评分: 8.7
# 电影名称: 高山下的花环
#  / 卫国军魂(港)  /  Wreaths at the Foot of the Mountain, 评分: 9.5
# 电影名称: 步履不停
#  / 歩いても 歩いても
#  / 横山家之味(港 / 台), 评分: 8.8
# 电影名称: 房间
#  / Room
#  / 不存在的房间(台)  /  抖室(港), 评分: 8.8
# 电影名称: 魂断蓝桥
#  / Waterloo Bridge
#  / 滑铁卢桥  /  断桥残梦, 评分: 8.8
# 电影名称: 千年女优
#  / 千年女優
#  / Millennium Actress, 评分: 8.8
# 电影名称: 哈利·波特与凤凰社
#  / Harry Potter and the Order of the Phoenix
#  / 哈利波特5：凤凰会的密令(港 / 台), 评分: 8.5
# 电影名称: 谍影重重2
#  / The Bourne Supremacy
#  / 叛谍追击2：机密圈套(港)  /  神鬼认证：神鬼疑云(台), 评分: 8.7
# 电影名称: 蜘蛛侠：平行宇宙
#  / Spider-Man: Into the Spider-Verse
#  / 蜘蛛侠：新纪元  /  蜘蛛人：新宇宙(台), 评分: 8.6
# 电影名称: 大红灯笼高高挂
#  / Raise The Red Lantern  /  Épouses et concubines, 评分: 8.8
# 电影名称: 弱点
#  / The Blind Side
#  / 守护有心人(港)  /  攻其不备(台), 评分: 8.7
# 电影名称: 谍影重重
#  / The Bourne Identity
#  / 叛谍追击(港)  /  神鬼认证(台), 评分: 8.6
# 电影名称: 阿飞正传
#  / 阿飛正傳
#  / Days of Being Wild, 评分: 8.5
# 电影名称: 朗读者
#  / The Reader
#  / 为爱朗读(台)  /  读爱(港), 评分: 8.6
# 电影名称: 再次出发之纽约遇见你
#  / Begin Again
#  / 再次出发  /  歌曲改变人生, 评分: 8.6
# 电影名称: 燃情岁月
#  / Legends of the Fall
#  / 秋日传奇  /  真爱一世情(台), 评分: 8.7

# %% [markdown]
# ### 1c) Collecting into a dataframe
#
# Create a dataframe `movie_df` and add the data from the lists above to it.
# - `movie_name` is the movie name. Set the column name as `movie name`
# - `movie_star` is the population estimate via star. Add it to the dataframe, and set the column name as `movie star`
#
# Make sure to check the head of your dataframe to see that everything looks right! ie: movie_df.head()
#
# Finally, you should save the DataFrame to a csv file under this folder`'./output'`.

# %%
csv_name =  "MovieDouban.csv" #csv_name =  "All-MovieDouban.csv"
csv_dir = "./output"

# # YOUR CODE HERE
# raise NotImplementedError()
movie_df = pd.DataFrame({
    'movie name': movie_name,
    'movie star': movie_star
})

print(movie_df.head())

movie_df.to_csv(f"{csv_dir}/{csv_name}", index=False)
# Out:
#                                           movie name movie star
# 0  肖申克的救赎\n / The Shawshank Redemption\n / 月黑高飞(港...        9.7
# 1          霸王别姬\n / 再见，我的妾  /  Farewell My Concubine        9.6
# 2                  阿甘正传\n / Forrest Gump\n / 福雷斯特·冈普        9.5
# 3                  泰坦尼克号\n / Titanic\n / 铁达尼号(港 / 台)        9.5
# 4          千与千寻\n / 千と千尋の神隠し\n / 神隐少女(台)  /  千与千寻的神隐        9.4

# %% [markdown]
# ## Part 2: JSON File Analysis
#
# After the initial phase of web scraping, we transition to analyzing pre-collected data, which is often stored in accessible and structured formats like JSON and CSV. This approach allows us to bypass the time-consuming process of data collection through web scraping for certain datasets that are already available, enabling us to dive directly into data analysis.

# %% [markdown]
# ### Overview
# In the section, you will first be working with a file called 'anon_user_dat.json'. You can find the given data under the folder `'./data/data_identifying'`. This file contains information about some (fake) Tinder users. When creating an account, each Tinder user was asked to provide their first name, last name, work email (to verify the disclosed workplace), age, gender, phone # and zip code. Before releasing this data, a data scientist cleaned the data to protect the privacy of Tinder's users by removing the obvious personal identifiers: phone #, zip code, and IP address. However, the data scientist chose to keep each users' email addresses because when they visually skimmed a couple of the email addresses none of them seemed to have any of the users' actual names in them. This is where the data scientist made a huge mistake!
#
# Data Files:
# - anon_user_dat.json
# - employee_info.json
#
#
# We will take advantage of having the work email addresses by finding the employee information of different companies and matching that employee information with the information we have, in order to identify the names of the secret Tinder users!

# %% [markdown]
# ### 2a) Load data from JSON file
#
# Load the `anon_user_dat.json` json file into a pandas dataframe. Call it `df_personal`.

# %%
# YOUR CODE HERE
# raise NotImplementedError()

json_file = './data/data_identifying/anon_user_dat.json'
df_personal = pd.read_json(json_file)

# %%
assert isinstance(df_personal, pd.DataFrame)

# %% [markdown]
# ### 2b) Check the first 10 emails
#
# Save the first 10 emails to a Series, and call it `sample_emails`.
# You should then print out this Series. ( Use print() )
#
# The purpose of this is to get a sense of how these work emails are structured and how we could possibly extract where each anonymous user seems to work.

# %%
# YOUR CODE HERE
# raise NotImplementedError()
sample_emails = df_personal['email'].head(10)
print(sample_emails)
# Out:
# 0    gshoreson0@seattletimes.com
# 1             eweaben1@salon.com
# 2        akillerby2@gravatar.com
# 3              gsainz3@zdnet.com
# 4       bdanilewicz4@4shared.com
# 5      sdeerness5@wikispaces.com
# 6         jstillwell6@ustream.tv
# 7         mpriestland7@opera.com
# 8       nerickssen8@hatena.ne.jp
# 9             hparsell9@xing.com
# Name: email, dtype: object

# %%
assert isinstance(sample_emails, pd.Series)

# %% [markdown]
# ### 2c) Extract the Company Name From the Email
#
# Create a function with the following specifications:
# - Function Name: extract_company
# - Purpose: to extract the company of the email (i.e., everything after the @ sign but before the first .)
# - Parameter(s): email (string)
# - Returns: The extracted part of the email (string)
# - Hint: This should take 1 line of code. Look into the find('') method.
#
# You can start with this outline:
# ```python
# def extract_company(email):
#     return
# ```
#
# Example Usage:
# - extract_company("larhe@uber.com") should return "uber"
# - extract_company(“ds@cogs.edu”) should return “cogs”

# %%
# YOUR CODE HERE
# raise NotImplementedError()
def extract_company(email):
    return email.split('@')[1].split('.')[0]

# %%
assert extract_company("gshoreson0@seattletimes.com") == "seattletimes"
assert extract_company("amcgeffen1d@goo.ne.jp") == 'goo'

# %% [markdown]
# With a little bit of basic sleuthing (aka googling) and web-scraping (aka selectively reading in html code) it turns out that you've been able to collect information about all the present employees/interns of the companies you are interested in. Specifically, on each company website, you have found the name, gender, and age of its employees. You have saved that info in employee_info.json and plan to see if, using this new information, you can match the Tinder accounts to actual names.

# %% [markdown]
# ### 2d) Load in employee data
#
# Load the json file into a pandas dataframe. Call it `df_employee`.

# %%
# YOUR CODE HERE
# raise NotImplementedError()

json_file = './data/data_identifying/employee_info.json'
df_employee = pd.read_json(json_file)

# %%
assert isinstance(df_employee, pd.DataFrame)

# %% [markdown]
# ### 2e) Match the employee name with company, age, gender
#
# Create a function with the following specifications:
# - Function name: employee_matcher
# - Purpose: to match the employee name with the provided company, age, and gender
# - Parameter(s): company (string), age (int), gender (string)
# - Returns: The employee first_name and last_name like this: return first_name, last_name
# - Note: If there are multiple employees that fit the same description, first_name and last_name should return a list of all possible first names and last names i.e., ['Desmund', 'Kelby'], ['Shepley', 'Tichner']. Note that the names of the individuals that would produce this output are 'Desmund Shepley' and 'Kelby Tichner'.
#
# Hint:
# There are many different ways to code this. An inelegant solution is to loop through `df_employee`
#    and for each data item see if the company, age, and gender match
#    i.e.,
#    ```python
#    for i in range(0, len(df_employee)):
#              if (company == df_employee.loc[i,'company']):
#    ```
#
# However! The solution above is very inefficient and long, so you should try to look into this:
# Google the df.loc method: It extracts pieces of the dataframe
#    if it fulfills a certain condition.
#    i.e.,
#
# ```python
# df_employee.loc[df_employee['company'] == company]
# ```
#
# If you need to convert your pandas data series into a list, you can do ```list(result)``` where result is a pandas "series"
#
# You can start with this outline:
# ```python
# def employee_matcher(company, age, gender):
#     return first_name, last_name
# ```

# %%
# YOUR CODE HERE
# raise NotImplementedError()
def employee_matcher(company, age, gender):
    result = df_employee.loc[(df_employee['company'] == company) & (df_employee['age'] == age) & (df_employee['gender'] == gender), ['first_name', 'last_name']]
    
    if len(result) == 0:
        return "No matching employees found"
    
    first_names = result['first_name'].tolist()
    last_names = result['last_name'].tolist()

    return first_names, last_names

# %%
assert employee_matcher("google", 41, "Male") == (['Maxwell'], ['Jorio'])
assert employee_matcher("salon", 47, "Female") == (['Elenore'], ['Gravett'])
assert employee_matcher("webmd", 28, "Nonbinary") == (['Zaccaria'], ['Bartosiak'])

# %% [markdown]
# ### 2f) Extract all the private data
#
# - Create 2 empty lists called `first_names` and `last_names`
# - Loop through all the people we are trying to identify in df_personal
# - Call the `extract_company` function (i.e., `extract_company(df_personal.loc[i, 'email'])` )
# - Call the `employee_matcher` function
# - Append the results of `employee_matcher` to the appropriate lists (`first_names` and `last_names`)

# %%
# YOUR CODE HERE
# raise NotImplementedError()
first_names = []
last_names = []

for i in range(len(df_personal)):
    email = df_personal.loc[i, 'email']
    company = extract_company(email)
    age = df_personal.loc[i, 'age']
    gender = df_personal.loc[i, 'gender']
    
    result = employee_matcher(company, age, gender)
    
    first_names.append(result[0])
    last_names.append(result[1])

# %%
assert first_names[45:50]== [['Justino'], ['Tadio'], ['Kennith'], ['Cedric'], ['Amargo']]
assert last_names[45:50] == [['Corro'], ['Blackford'], ['Milton'], ['Yggo'], ['Grigor']]

# %% [markdown]
# ### 2g) Add the names to the original 'secure' dataset!
#
# We have done this last step for you below, all you need to do is run this cell.
#
# For your own personal enjoyment, you should also print out the new `df_personal` with the identified people.

# %%
df_personal['first_name'] = first_names
df_personal['last_name'] = last_names
print(df_personal)
# Out:
#      age                        email  gender           first_name  \
# 0     60  gshoreson0@seattletimes.com    Male             [Gordon]
# 1     47           eweaben1@salon.com  Female            [Elenore]
# 2     27      akillerby2@gravatar.com    Male               [Abbe]
# 3     46            gsainz3@zdnet.com    Male              [Guido]
# 4     72     bdanilewicz4@4shared.com    Male              [Brody]
# ..   ...                          ...     ...                  ...
# 995    3        pstroulgerrn@time.com  Female           [Penelopa]
# 996   49  kbasnettro@seattletimes.com  Female  [Anthiathia, Kandy]
# 997   75  pmortlockrp@liveinternet.ru    Male               [Paco]
# 998   81         sphetterq@toplist.cz    Male              [Sammy]
# 999   70        jtyresrr@slashdot.org    Male             [Josiah]
#
#              last_name
# 0          [DelaField]
# 1            [Gravett]
# 2          [Stockdale]
# 3            [Comfort]
# 4           [Pinckard]
# ..                 ...
# 995            [Roman]
# 996  [Baldwin, Cossam]
# 997      [Weatherburn]
# 998           [Dymick]
# 999         [Ayshford]
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Part 3: Working with CSV Files
# Continuing with our exploration of pre-collected data formats, we delve into CSV files, which are renowned for their simplicity and widespread use in representing tabular data. This stage involves leveraging libraries like pandas in Python, which simplify the process of reading, manipulating, and analyzing CSV data.
#
# ### Overview
#
# For this assignment, you are provided with two data files that contain information on a sample of people. The two files and their columns are:
#
# - `age_steps.csv`: Contains one row for each person.
#     - `id`: Unique identifier for the person.
#     - `age`: Age of the person.
#     - `steps`: Number of steps the person took on average in January 2018.
#
#
# - `incomes.json`: Contains one record for each person.
#     - `id`: Unique identifier for the person. Two records with the same ID between `age_steps.csv` and `incomes.json` correspond to the same person.
#     - `last_name`: Last name of the person.
#     - `first_name`: First name of the person.
#     - `income`: Income of the person in 2018.
#
# You can find the given data under the folder `'./data/data_wrangling'`. To finish the assignment, we recommend looking at the official 10 minutes to pandas guide: http://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# **Question 3a:** Load the `age_steps.csv` file into a `pandas` DataFrame named `df_steps`. It should have 11257 rows and 3 columns.

# %%
# YOUR CODE HERE
# raise NotImplementedError()

df_steps = pd.read_csv('./data/data_wrangling/age_steps.csv')

print(df_steps.shape)
print(df_steps.head())
# Out:
# (11257, 3)
#       id  age  steps
# 0  18875   31   9159
# 1  36859   48   6764
# 2  99794   39   4308
# 3  33364   36   6410
# 4  73874   35   7870

# %%
assert isinstance(df_steps, pd.DataFrame)
assert df_steps.shape == (11257, 3)

# %% [markdown]
# **Question 3b:** Load the `incomes.json` file into a `pandas` DataFrame called `df_income`. The DataFrame should have 13332 rows and 4 columns.
#
# Hint: Find a pandas function similar to `read_csv` for JSON files.

# %%
# YOUR CODE HERE
# raise NotImplementedError()
df_income = pd.read_json('./data/data_wrangling/incomes.json')

print(df_income.shape)
print(df_income.head())
# Out:
# (13332, 4)
#       id last_name first_name    income
# 0  84764     Wolfe      Brian  99807.16
# 1  49337     Keith     George      0.00
# 2  54204    Wilcox    Zachary   5242.96
# 3  41693     Glass  Catherine      0.00
# 4  98170     Perez        Bob  18077.78

# %%
assert isinstance(df_income, pd.DataFrame)
assert df_income.shape == (13332, 4)

# %% [markdown]
# **Question 3c:** Drop the `first_name` and `last_name` columns from the `df_income` DataFrame. The resulting DataFrame should only have two columns.

# %%
# YOUR CODE HERE
# raise NotImplementedError()
df_income = df_income.drop(['first_name', 'last_name'], axis=1)

# %%
assert 'first_name' not in df_income.columns
assert 'last_name' not in df_income.columns

# %% [markdown]
# **Question 3d:** Merge the `df_steps` and `df_income` DataFrames into a single combined DataFrame called `df`. Use the `id` column to match rows together.
#
# The final DataFrame should have 10,135 rows and 4 columns: `id`, `income`, `age`, and `steps`.
#
# Call an appropriate `pandas` method to perform this operation; don't write a `for` loop. (In general, writing a `for` loop for a DataFrame will produce poor results.)

# %%
# YOUR CODE HERE
# raise NotImplementedError()
df = df_steps.merge(df_income, on='id')

# %%
assert isinstance(df, pd.DataFrame)
assert set(df.columns) == set(['id', 'income', 'age', 'steps'])
assert df.shape == (10135, 4)

# %% [markdown]
# **Question 3e:** Reorder the columns of `df` so that they appear in the order: `id`, `age`, `steps`, then `income`.
#
# (Note: If your DataFrame is already in this order, just put `df` in this cell.)

# %%
# YOUR CODE HERE
# raise NotImplementedError()
df = df[['id', 'age', 'steps', 'income']]

# %%
assert list(df.columns) == ['id', 'age', 'steps', 'income']

# %% [markdown]
# **Question 3f:** You may have noticed something strange: the merged `df` DataFrame has fewer rows than either of `df_steps` and `df_income`. Why did this happen? (If you're unsure, check out the documentation for the `pandas` method you used to merge these two datasets. Take note of the default values set for this method's parameters.)
#
# Please select the **one** correct explanation below and save your answer in the variable `q1f_answer`. For example, if you believe choice number 4 explains why `df` has fewer rows, set `q1f_answer = 4`.
#
# 1. Some steps were recorded inaccurately in `df_steps`.
# 2. Some incomes were recorded inaccurately in `df_income`.
# 3. There are fewer rows in `df_steps` than in `df_income`.
# 4. There are fewer columns in `df_steps` than in `df_income`.
# 5. Some `id` values in either `df_steps` and `df_income` were missing in the other DataFrame.
# 6. Some `id` values were repeated in `df_steps` and in `df_income`.
#
# You may use the cell below to run whatever code you want to check the statements above. Just make sure to set `q1f_answer` once you've selected a choice.

# %%
# YOUR CODE HERE
# raise NotImplementedError()
q1f_answer=5

# %%
assert isinstance(q1f_answer, int)

# %% [markdown]
# ## Part 4 - Data Cleaning
#
# Post data collection, a pivotal step ensues—Data Cleaning. This phase is crucial for ensuring the reliability and accuracy of our analysis. It involves scrutinizing the data for inaccuracies, inconsistencies, and incompleteness. Techniques such as removing duplicates, handling missing values, and correcting errors are employed to refine the dataset. A common phenomenon is that the collected data may contain missing values. Here are two common ones:
#
# - **Nonresponse.** For example, people might have left a field blank when responding to a survey, or left the entire survey blank.
# - **Lost in entry.** Data might have been lost after initial recording. For example, a disk cleanup might accidentally wipe older entries of a database.
#
# In general, it is **not** appropriate to simply drop missing values from the dataset or pretend that if filled in they would not change your results. In 2016, many polls mistakenly predicted that Hillary Clinton would easily win the Presidential election by committing this error. In this particular dataset, however, the **missing values occur completely at random**. This criteria allows us to drop missing values without significantly affecting our conclusions.
#
# In this section, we continue use the data mentioned in Part 3.

# %% [markdown]
# **Question 4a:** How many values are missing in the `income` column of `df`? Save this number into a variable called `n_nan`.

# %%
# YOUR CODE HERE
# raise NotImplementedError()
n_nan = df['income'].isnull().sum()
print(n_nan)
# Out:
# 451

# %%
assert(n_nan)

# %% [markdown]
# **Question 4b:** Remove all rows from `df` that have missing values.

# %%
# Remove all rows from df that have missing data. In other words, remove all rows with NaN values.

# YOUR CODE HERE
# raise NotImplementedError()

df.dropna(inplace=True)

# %%
assert sum(np.isnan(df['income'])) == 0
assert df.shape == (9684, 4)

# %% [markdown]
# **Question 4c:** Note that we can now compute the average income. If your `df` variable contains the right values, `df['income'].mean()` should produce the value `25508.84`.
#
# Suppose that we didn't drop the missing incomes. What will running `df['income'].mean()` output? Use the variable `q2c_answer` to record which of the below statements you think is true. As usual, you can use the cell below to run any code you'd like in order to help you answer this question as long as you set `q2c_answer` once you've finished.
#
# 1. No change; `df['income'].mean()` will ignore the missing values and output `25508.84`.
# 2. `df['income'].mean()` will produce an error.
# 3. `df['income'].mean()` will output `0`.
# 4. `df['income'].mean()` will output `nan` (not a number).
# 5. `df['income'].mean()` will fill in the missing values with the average income, then compute the average.
# 6. `df['income'].mean()` will fill in the missing values with `0`, then compute the average.

# %%
# YOUR CODE HERE
# raise NotImplementedError()

q2c_answer=4

# %%
assert isinstance(q2c_answer, int)

# %% [markdown]
# **Question 4d:** Suppose that missing incomes did not occur at random, and that individuals with incomes below \$10000 a year are less likely to report their incomes. If so, which of the following statements below is true? Record your choice in the variable `q2d_answer`.
#
# 1. `df['income'].mean()` will likely output a value that is the same as the population's average income
# 2. `df['income'].mean()` will likely output a value that is smaller than the population's average income.
# 3. `df['income'].mean()` will likely output a value that is larger than the population's average income.
# 4. `df['income'].mean()` will raise an error.

# %%
# YOUR CODE HERE
# raise NotImplementedError()

q2d_answer=3

# %%
assert isinstance(q2d_answer, int)

# %% [markdown]
# ## Complete!
#
# Congrats, you're done!
